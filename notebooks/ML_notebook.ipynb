# %% [markdown]
# # Machine Learning Pipeline

# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import teamestimatedmetrics
from nba_api.stats.endpoints import playernextngames
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ### Return a list of dictionnary

# %%
def get_active_players():
    active_players = players.get_active_players()
    return active_players

active_players = get_active_players()
print(active_players)
# Out:
# [{'id': 1630173, 'full_name': 'Precious Achiuwa', 'first_name': 'Precious', 'last_name': 'Achiuwa', 'is_active': True}, {'id': 203500, 'full_name': 'Steven Adams', 'first_name': 'Steven', 'last_name': 'Adams', 'is_active': True}, {'id': 1628389, 'full_name': 'Bam Adebayo', 'first_name': 'Bam', 'last_name': 'Adebayo', 'is_active': True}, {'id': 1630534, 'full_name': 'Ochai Agbaji', 'first_name': 'Ochai', 'last_name': 'Agbaji', 'is_active': True}, {'id': 1630583, 'full_name': 'Santi Aldama', 'first_name': 'Santi', 'last_name': 'Aldama', 'is_active': True}, {'id': 1629638, 'full_name': 'Nickeil Alexander-Walker', 'first_name': 'Nickeil', 'last_name': 'Alexander-Walker', 'is_active': True}, {'id': 1628960, 'full_name': 'Grayson Allen', 'first_name': 'Grayson', 'last_name': 'Allen', 'is_active': True}, {'id': 1628386, 'full_name': 'Jarrett Allen', 'first_name': 'Jarrett', 'last_name': 'Allen', 'is_active': True}, {'id': 1630631, 'full_name': 'Jose Alvarado', 'first_name': 'Jose', 'last_name': 'Alvarado', 'is_active': True}, {'id': 203937, 'full_name': 'Kyle Anderson', 'first_name': 'Kyle', 'last_name': 'Anderson', 'is_active': True}, {'id': 203507, 'full_name': 'Giannis Antetokounmpo', 'first_name': 'Giannis', 'last_name': 'Antetokounmpo', 'is_active': True}, {'id': 203648, 'full_name': 'Thanasis Antetokounmpo', 'first_name': 'Thanasis', 'last_name': 'Antetokounmpo', 'is_active': True}, {'id': 1630175, 'full_name': 'Cole Anthony', 'first_name': 'Cole', 'last_name': 'Anthony', 'is_active': True}, {'id': 1628384, 'full_name': 'OG Anunoby', 'first_name': 'OG', 'last_name': 'Anunoby', 'is_active': True}, {'id': 1627853, 'full_name': 'Ryan Arcidiacono', 'first_name': 'Ryan', 'last_name': 'Arcidiacono', 'is_active': True}, {'id': 1630166, 'full_name': 'Deni Avdija', 'first_name': 'Deni', 'last_name': 'Avdija', 'is_active': True}, {'id': 1629028, 'full_name': 'Deandre Ayton', 'first_name': 'Deandre', 'last_name': 'Ayton', 'is_active': True}, {'id': 1628962, 'full_name': 'Udoka Azubuike', 'first_name': 'Udoka', 'last_name': 'Azubuike', 'is_active': True}, {'id': 1628963, 'full_name': 'Marvin Bagley III', 'first_name': 'Marvin', 'last_name': 'Bagley III', 'is_active': True}, {'id': 1641735, 'full_name': 'Amari Bailey', 'first_name': 'Amari', 'last_name': 'Bailey', 'is_active': True}, {'id': 1631116, 'full_name': 'Patrick Baldwin Jr.', 'first_name': 'Patrick', 'last_name': 'Baldwin Jr.', 'is_active': True}, {'id': 1630163, 'full_name': 'LaMelo Ball', 'first_name': 'LaMelo', 'last_name': 'Ball', 
            print(f"Erreur lors de la récupération des données pour le joueur (ID: {player_id}): {e}")

    if all_players_stats_list:
        all_players_stats = pd.concat(all_players_stats_list, ignore_index=True)
        return all_players_stats
    else:
        return pd.DataFrame()

# %%
def get_perf_players_each_season(list_of_seasons):
    active_players = players.get_active_players()
    player_ids = [d.get('id') for d in active_players]
    
    all_seasons_stats_list = []

    for season in list_of_seasons:
        season_stats = fetch_nba_player_stats(season, player_ids)
        season_stats['Season'] = season  # Ajoute une colonne pour identifier la saison des stats
        all_seasons_stats_list.append(season_stats)

    # Concaténer tous les DataFrames de chaque saison en un seul DataFrame
    all_seasons_stats = pd.concat(all_seasons_stats_list, ignore_index=True)
    
    return all_seasons_stats

# Liste des saisons pour lesquelles récupérer les stats
list_of_seasons = ['2022-23', "2023-24"]

# %%
all_players_stats= get_perf_players_each_season(list_of_seasons)
# Out:
# C:\Users\BriacMarchandise\AppData\Local\Temp\ipykernel_20408\311310846.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat(all_players_stats_list, ignore_index=True)
# C:\Users\BriacMarchandise\AppData\Local\Temp\ipykernel_20408\311310846.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_players_stats = pd.concat(all_players_stats_list, ignore_index=True)

# %%
all_players_stats.head()
# Out:
#   SEASON_ID Player_ID     Game_ID     GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0     22022   1630173  0022201221  APR 09, 2023  TOR vs. MIL  W  28   6  11
# 1     22022   1630173  0022201206  APR 07, 2023    TOR @ BOS  L  24   6  10
# 2     22022   1630173  0022201192  APR 05, 2023    TOR @ BOS  L  20   7  11
# 3     22022   1630173  0022201176  APR 04, 2023    TOR @ CHA  W  15   4   8
# 4     22022   1630173  0022201163  APR 02, 2023    TOR @ CHA  W  13   4   7
#
#    FG_PCT  ... REB AST  STL BLK TOV  PF PTS PLUS_MINUS VIDEO_AVAILABLE  \
# 0   0.545  ...  13   1    2   0   2   2  14          9               1
# 1   0.600  ...   7   0    1   0   0   3  16         -9               1
# 2   0.636  ...   9   0    0   1   1   2  16         -4               1
# 3   0.500  ...   4   1    1   0   0   1  12          9               1
# 4   0.571  ...   3   0    0   0   1   0   8          6               1
#
#     Season
# 0  2022-23
# 1  2022-23
# 2  2022-23
# 3  2022-23
# 4  2022-23
#
# [5 rows x 28 columns]

# %%
all_players_stats.shape
# Out:
# (39815, 28)

# %%
all_players_stats['GAME_DATE'] = pd.to_datetime(all_players_stats['GAME_DATE'], format='%b %d, %Y')

col_type = all_players_stats["GAME_DATE"].dtypes
print(col_type)
# Out:
# datetime64[ns]

# %%
player_id_full_name = [{'Player_ID': d.get('id'), 'full_name': d.get('full_name')} for d in active_players]

# %%
player_id_full_name_df = pd.DataFrame(player_id_full_name)
player_id_full_name_df.head()
# Out:
#    Player_ID         full_name
# 0    1630173  Precious Achiuwa
# 1     203500      Steven Adams
# 2    1628389       Bam Adebayo
# 3    1630534      Ochai Agbaji
# 4    1630583      Santi Aldama

# %%
stat_player_game_with_names = pd.merge(all_players_stats, player_id_full_name_df, on='Player_ID', how='inner')

columns_order = [col for col in player_id_full_name_df.columns if col != 'id'] + [col for col in all_players_stats.columns if col != 'id']
stat_player_game_with_names = stat_player_game_with_names[columns_order]

stat_player_game_with_names.tail(10)
# Out:
#       Player_ID    full_name SEASON_ID Player_ID     Game_ID  GAME_DATE  \
# 39805   1627826  Ivica Zubac     22023   1627826  0022300024 2023-11-14
# 39806   1627826  Ivica Zubac     22023   1627826  0022300179 2023-11-12
# 39807   1627826  Ivica Zubac     22023   1627826  0022300014 2023-11-10
# 39808   1627826  Ivica Zubac     22023   1627826  0022300160 2023-11-08
# 39809   1627826  Ivica Zubac     22023   1627826  0022300151 2023-11-06
# 39810   1627826  Ivica Zubac     22023   1627826  0022300127 2023-11-01
# 39811   1627826  Ivica Zubac     22023   1627826  0022300114 2023-10-31
# 39812   1627826  Ivica Zubac     22023   1627826  0022300099 2023-10-29
# 39813   1627826  Ivica Zubac     22023   1627826  0022300085 2023-10-27
# 39814   1627826  Ivica Zubac     22023   1627826  0022300074 2023-10-25
#
#            MATCHUP WL MIN FGM  ... REB  AST STL BLK  TOV PF PTS  PLUS_MINUS  \
# 39805    LAC @ DEN  L  26   2  ...  13    3   0   1    0  4   9          -3
# 39806  LAC vs. MEM  L  23   2  ...   6    1   1   0    1  3   6          -6
# 39807    LAC @ DAL  L  22   5  ...   8    1   0   2    1  3  12           1
# 39808    LAC @ BKN  L  29   5  ...  10    1   0   3    1  5  10         -11
# 39809    LAC @ NYK  L  30   3  ...   7    0   1   2    5  3   8         -18
# 39810    LAC @ LAL  L  29   3  ...   9    0   0   0    1  5   7          -6
# 39811  LAC vs. ORL  W  23   4  ...   9    1   0   1    1  1   9          19
# 39812  LAC vs. SAS  W  22   6  ...   8    0   0   1    1  4  16          23
# 39813    LAC @ UTA  L  19   3  ...   2    0   0   2    1  2   6           1
# 39814  LAC vs. POR  W  26   8  ...  12    0   0   4    2  3  20          25
#
#       VIDEO_AVAILABLE   Season
# 39805               1  2023-24
# 39806               1  2023-24
# 39807               1  2023-24
# 39808               1  2023-24
# 39809               1  2023-24
# 39810               1  2023-24
# 39811               1  2023-24
# 39812               1  2023-24
# 39813               1  2023-24
# 39814               1  2023-24
#
# [10 rows x 30 columns]

# %%
stat_player_game_with_names.columns
# Out:
# Index(['Player_ID', 'full_name', 'SEASON_ID', 'Player_ID', 'Game_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE',
#        'Season'],
#       dtype='object')

# %%
stat_player_game_with_names.head()
# Out:
#   Player_ID         full_name SEASON_ID Player_ID     Game_ID  GAME_DATE  \
# 0   1630173  Precious Achiuwa     22022   1630173  0022201221 2023-04-09
# 1   1630173  Precious Achiuwa     22022   1630173  0022201206 2023-04-07
# 2   1630173  Precious Achiuwa     22022   1630173  0022201192 2023-04-05
# 3   1630173  Precious Achiuwa     22022   1630173  0022201176 2023-04-04
# 4   1630173  Precious Achiuwa     22022   1630173  0022201163 2023-04-02
#
#        MATCHUP WL MIN FGM  ... REB  AST STL BLK  TOV PF PTS  PLUS_MINUS  \
# 0  TOR vs. MIL  W  28   6  ...  13    1   2   0    2  2  14           9
# 1    TOR @ BOS  L  24   6  ...   7    0   1   0    0  3  16          -9
# 2    TOR @ BOS  L  20   7  ...   9    0   0   1    1  2  16          -4
# 3    TOR @ CHA  W  15   4  ...   4    1   1   0    0  1  12           9
# 4    TOR @ CHA  W  13   4  ...   3    0   0   0    1  0   8           6
#
#   VIDEO_AVAILABLE   Season
# 0               1  2022-23
# 1               1  2022-23
# 2               1  2022-23
# 3               1  2022-23
# 4               1  2022-23
#
# [5 rows x 30 columns]

# %% [markdown]
# #

# %% [markdown]
# #

# %%
all_players_stats_1 = pd.read_csv("../dataset/player_stats_all_2024-02-09 17-06-12.csv")

# %%
all_players_stats_1.head()
# Out:
#    Player_ID     full_name  SEASON_ID  Player_ID.1   Game_ID   GAME_DATE  \
# 0     203500  Steven Adams      22019       203500  21901317  2020-08-14
# 1     203500  Steven Adams      22019       203500  21901306  2020-08-12
# 2     203500  Steven Adams      22019       203500  21901265  2020-08-05
# 3     203500  Steven Adams      22019       203500  21901251  2020-08-03
# 4     203500  Steven Adams      22019       203500  21901240  2020-08-01
#
#        MATCHUP WL  MIN  FGM  ...  REB  AST  STL  BLK  TOV  PF  PTS  \
# 0    OKC @ LAC  L    6    0  ...    4    0    0    0    1   0    0
# 1  OKC vs. MIA  W   20    4  ...    8    0    1    0    0   0    8
# 2    OKC @ LAL  W   28    7  ...    7    2    0    0    1   2   18
# 3  OKC vs. DEN  L   34    3  ...   10    1    0    0    2   6    9
# 4  OKC vs. UTA  W   28    7  ...   11    2    0    2    4   3   16
#
#    PLUS_MINUS  VIDEO_AVAILABLE   Season
# 0           2                1  2019-20
# 1          -7                1  2019-20
# 2          13                1  2019-20
# 3         -18                1  2019-20
# 4          15                1  2019-20
#
# [5 rows x 30 columns]

# %%
def concat_dataframe(df1, df2):

    df_concat = pd.concat([df1, df2], axis=0)
    return df_concat

# %%
all_players_stats_full = concat_dataframe(all_players_stats_1, stat_player_game_with_names)

# %%
print("shape = ", all_players_stats_full.shape)
all_players_stats_full.head()
# Out:
# shape =  (89923, 30)
#       full_name SEASON_ID   Game_ID   GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0  Steven Adams     22019  21901317  2020-08-14    OKC @ LAC  L   6   0   2
# 1  Steven Adams     22019  21901306  2020-08-12  OKC vs. MIA  W  20   4   7
# 2  Steven Adams     22019  21901265  2020-08-05    OKC @ LAL  W  28   7  10
# 3  Steven Adams     22019  21901251  2020-08-03  OKC vs. DEN  L  34   3   6
# 4  Steven Adams     22019  21901240  2020-08-01  OKC vs. UTA  W  28   7  10
#
#    FG_PCT  ... STL BLK  TOV PF PTS  PLUS_MINUS VIDEO_AVAILABLE   Season  \
# 0   0.000  ...   0   0    1  0   0           2               1  2019-20
# 1   0.571  ...   1   0    0  0   8          -7               1  2019-20
# 2   0.700  ...   0   0    1  2  18          13               1  2019-20
# 3   0.500  ...   0   0    2  6   9         -18               1  2019-20
# 4   0.700  ...   0   2    4  3  16          15               1  2019-20
#
#   Player_ID Player_ID
# 0    203500    203500
# 1    203500    203500
# 2    203500    203500
# 3    203500    203500
# 4    203500    203500
#
# [5 rows x 30 columns]

# %%
columns_to_keep = all_players_stats_full.columns.drop('Player_ID', 1).tolist() + ['Player_ID']
# Sélectionnez ces colonnes, ce qui aura pour effet de ne garder que la première occurrence de "age"
all_players_stats_full = all_players_stats_full.loc[:, columns_to_keep]

# %%
all_players_stats_full = all_players_stats_full.iloc[:, :29]

# %%
all_players_stats_full.head()
# Out:
#       full_name SEASON_ID   Game_ID   GAME_DATE      MATCHUP WL MIN FGM FGA  \
# 0  Steven Adams     22019  21901317  2020-08-14    OKC @ LAC  L   6   0   2
# 1  Steven Adams     22019  21901306  2020-08-12  OKC vs. MIA  W  20   4   7
# 2  Steven Adams     22019  21901265  2020-08-05    OKC @ LAL  W  28   7  10
# 3  Steven Adams     22019  21901251  2020-08-03  OKC vs. DEN  L  34   3   6
# 4  Steven Adams     22019  21901240  2020-08-01  OKC vs. UTA  W  28   7  10
#
#    FG_PCT  ... AST STL  BLK TOV PF  PTS PLUS_MINUS VIDEO_AVAILABLE   Season  \
# 0   0.000  ...   0   0    0   1  0    0          2               1  2019-20
# 1   0.571  ...   0   1    0   0  0    8         -7               1  2019-20
# 2   0.700  ...   2   0    0   1  2   18         13               1  2019-20
# 3   0.500  ...   1   0    0   2  6    9        -18               1  2019-20
# 4   0.700  ...   2   0    2   4  3   16         15               1  2019-20
#
#   Player_ID
# 0    203500
# 1    203500
# 2    203500
# 3    203500
# 4    203500
#
# [5 rows x 29 columns]

# %%
new_order = ["Player_ID"] + [col for col in all_players_stats_full.columns if col != "Player_ID"]

all_players_stats_full = all_players_stats_full[new_order]

# %%
all_players_stats_full.tail()
# Out:
#       Player_ID    full_name SEASON_ID     Game_ID            GAME_DATE  \
# 39810   1627826  Ivica Zubac     22023  0022300127  2023-11-01 00:00:00
# 39811   1627826  Ivica Zubac     22023  0022300114  2023-10-31 00:00:00
# 39812   1627826  Ivica Zubac     22023  0022300099  2023-10-29 00:00:00
# 39813   1627826  Ivica Zubac     22023  0022300085  2023-10-27 00:00:00
# 39814   1627826  Ivica Zubac     22023  0022300074  2023-10-25 00:00:00
#
#            MATCHUP WL MIN FGM FGA  ...  DREB REB AST  STL BLK TOV  PF PTS  \
# 39810    LAC @ LAL  L  29   3   8  ...     7   9   0    0   0   1   5   7
# 39811  LAC vs. ORL  W  23   4   8  ...     7   9   1    0   1   1   1   9
# 39812  LAC vs. SAS  W  22   6   7  ...     6   8   0    0   1   1   4  16
# 39813    LAC @ UTA  L  19   3   6  ...     2   2   0    0   2   1   2   6
# 39814  LAC vs. POR  W  26   8  10  ...     7  12   0    0   4   2   3  20
#
#       PLUS_MINUS   Season
# 39810         -6  2023-24
# 39811         19  2023-24
# 39812         23  2023-24
# 39813          1  2023-24
# 39814         25  2023-24
#
# [5 rows x 28 columns]

# %%
all_players_stats_full.drop("VIDEO_AVAILABLE", axis = 1, inplace=True)

# %%
all_players_stats_full['GAME_DATE'] = pd.to_datetime(all_players_stats_full['GAME_DATE'])

col_type = all_players_stats_full["GAME_DATE"].dtypes
print(col_type)
# Out:
# datetime64[ns]

# %%
all_players_stats_full = all_players_stats_full.sort_values(by='GAME_DATE', ascending=False)

# %%
all_players_stats_full.reset_index()

# %%
all_players_stats_full.head()
# Out:
#       Player_ID          full_name SEASON_ID     Game_ID  GAME_DATE  \
# 33919    203488       Mike Muscala     22023  0022300741 2024-02-08
# 27256   1630245        Ayo Dosunmu     22023  0022300737 2024-02-08
# 30519   1641748  Andre Jackson Jr.     22023  0022300738 2024-02-08
# 30922   1630553       Keon Johnson     22023  0022300735 2024-02-08
# 31310   1631117     Walker Kessler     22023  0022300739 2024-02-08
#
#            MATCHUP WL MIN FGM FGA  ...  DREB REB AST  STL BLK TOV  PF PTS  \
# 33919    DET @ POR  W  17   2   5  ...     1   3   2    0   1   1   0   6
# 27256    CHI @ MEM  W  27   4   5  ...     0   0   2    0   0   2   2  10
# 30519  MIL vs. MIN  L  18   0   2  ...     1   1   3    1   0   1   0   0
# 30922  BKN vs. CLE  L  14   1   3  ...     0   2   0    2   0   1   2   3
# 31310    UTA @ PHX  L  27   4   6  ...     4   9   2    2   4   0   1  10
#
#       PLUS_MINUS   Season
# 33919        -15  2023-24
# 27256         -1  2023-24
# 30519        -11  2023-24
# 30922         -5  2023-24
# 31310         -5  2023-24
#
# [5 rows x 28 columns]

# %%
all_players_stats_full.dtypes
# Out:
# Player_ID             object
# full_name             object
# SEASON_ID             object
# Game_ID               object
# GAME_DATE     datetime64[ns]
# MATCHUP               object
# WL                    object
# MIN                   object
# FGM                   object
# FGA                   object
# FG_PCT               float64
# FG3M                  object
# FG3A                  object
# FG3_PCT              float64
# FTM                   object
# FTA                   object
# FT_PCT               float64
# OREB                  object
# DREB                  object
# REB                   object
# AST                   object
# STL                   object
# BLK                   object
# TOV                   object
# PF                    object
# PTS                   object
# PLUS_MINUS            object
# Season                object
# dtype: object

# %% [markdown]
# # Drop unseful data

# %% [markdown]
# #

# %% [markdown]
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %% [markdown]
# #

# %% [markdown]
# # Next player games

# %%
def fetch_next_player_games(existing_player_ids=[]):
    all_players_stats_list = []

    for player_id in existing_player_ids:
        try:
            # Récupération des données de jeux suivants pour le joueur
            gamelog = playernextngames.PlayerNextNGames(player_id=str(player_id))
            df = gamelog.get_data_frames()[0]
            
            # Ajout de l'ID du joueur dans une nouvelle colonne du DataFrame
            df['Player_ID'] = player_id  # Ajoute l'ID du joueur dans une nouvelle colonne
            
            all_players_stats_list.append(df)
        except Exception as e:
            print(f"Erreur lors de la récupération des données pour le joueur (ID: {player_id}): {e}")

    if all_players_stats_list:
        all_players_stats = pd.concat(all_players_stats_list, ignore_index=True)
        return all_players_stats
    else:
        return pd.DataFrame()

# %%
player_id = [d.get('id') for d in active_players]

next_players_games = fetch_next_player_games(player_id)
# Out:
# Erreur lors de la récupération des données pour le joueur (ID: 1641777): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 202687): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1629716): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1629717): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631219): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630528): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641731): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630700): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641926): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 203915): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631105): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641788): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1629232): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641718): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1628385): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 201980): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631199): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 203925): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641722): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630165): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630703): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641793): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1627863): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631093): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631170): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1629610): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631117): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630233): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631132): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631171): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641726): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631097): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641706): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631099): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641936): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 203506): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630196): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641764): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641811): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631157): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 201937): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631101): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630606): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631095): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631110): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631131): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1630688): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641717): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1641705): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1629623): Expecting value: line 1 column 1 (char 0)
# Erreur lors de la récupération des données pour le joueur (ID: 1631114): Expecting value: line 1 column 1 (char 0)

# %%
player_id_full_name = [{'Player_ID': d.get('id'), 'full_name': d.get('full_name')} for d in active_players]
player_id_full_name_df = pd.DataFrame(player_id_full_name)

# %%
next_players_games.head()
# Out:
#       GAME_ID     GAME_DATE  HOME_TEAM_ID  VISITOR_TEAM_ID HOME_TEAM_NAME  \
# 0  0022300755  FEB 10, 2024    1610612752       1610612754       New York
# 1  0022300765  FEB 12, 2024    1610612745       1610612752        Houston
# 2  0022300778  FEB 14, 2024    1610612753       1610612752        Orlando
# 3  0022300794  FEB 22, 2024    1610612755       1610612752   Philadelphia
# 4  0022300816  FEB 24, 2024    1610612752       1610612738       New York
#
#   VISITOR_TEAM_NAME HOME_TEAM_ABBREVIATION VISITOR_TEAM_ABBREVIATION  \
# 0           Indiana                    NYK                       IND
# 1          New York                    HOU                       NYK
# 2          New York                    ORL                       NYK
# 3          New York                    PHI                       NYK
# 4            Boston                    NYK                       BOS
#
#   HOME_TEAM_NICKNAME VISITOR_TEAM_NICKNAME GAME_TIME HOME_WL VISITOR_WL  \
# 0             Knicks                Pacers  07:30 PM   33-19      29-24
# 1            Rockets                Knicks  08:00 PM   23-27      33-19
# 2              Magic                Knicks  07:00 PM   28-24      33-19
# 3              76ers                Knicks  07:00 PM   30-20      33-19
# 4             Knicks               Celtics  08:30 PM   33-19      39-12
#
#    Player_ID
# 0    1630173
# 1    1630173
# 2    1630173
# 3    1630173
# 4    1630173

# %%
stat_player_game_with_names = pd.merge(next_players_games, player_id_full_name_df, on='Player_ID', how='right')

# %%
stat_player_game_with_names.head()
# Out:
#       GAME_ID     GAME_DATE  HOME_TEAM_ID  VISITOR_TEAM_ID HOME_TEAM_NAME  \
# 0  0022300755  FEB 10, 2024  1.610613e+09     1.610613e+09       New York
# 1  0022300765  FEB 12, 2024  1.610613e+09     1.610613e+09        Houston
# 2  0022300778  FEB 14, 2024  1.610613e+09     1.610613e+09        Orlando
# 3  0022300794  FEB 22, 2024  1.610613e+09     1.610613e+09   Philadelphia
# 4  0022300816  FEB 24, 2024  1.610613e+09     1.610613e+09       New York
#
#   VISITOR_TEAM_NAME HOME_TEAM_ABBREVIATION VISITOR_TEAM_ABBREVIATION  \
# 0           Indiana                    NYK                       IND
# 1          New York                    HOU                       NYK
# 2          New York                    ORL                       NYK
# 3          New York                    PHI                       NYK
# 4            Boston                    NYK                       BOS
#
#   HOME_TEAM_NICKNAME VISITOR_TEAM_NICKNAME GAME_TIME HOME_WL VISITOR_WL  \
# 0             Knicks                Pacers  07:30 PM   33-19      29-24
# 1            Rockets                Knicks  08:00 PM   23-27      33-19
# 2              Magic                Knicks  07:00 PM   28-24      33-19
# 3              76ers                Knicks  07:00 PM   30-20      33-19
# 4             Knicks               Celtics  08:30 PM   33-19      39-12
#
#    Player_ID         full_name
# 0    1630173  Precious Achiuwa
# 1    1630173  Precious Achiuwa
# 2    1630173  Precious Achiuwa
# 3    1630173  Precious Achiuwa
# 4    1630173  Precious Achiuwa

# %%
# Supposons que df est votre DataFrame

# Identifier les deux dernières colonnes
last_two_columns = stat_player_game_with_names.columns[-2:]

# Identifier les autres colonnes
other_columns = stat_player_game_with_names.columns[:-2]

# Créer une nouvelle liste d'ordre des colonnes
new_column_order = list(last_two_columns) + list(other_columns)

# Réorganiser le DataFrame avec le nouvel ordre des colonnes
stat_player_game_with_names = stat_player_game_with_names[new_column_order]

# Afficher le DataFrame réorganisé
stat_player_game_with_names.head()
# Out:
#    Player_ID         full_name     GAME_ID     GAME_DATE  HOME_TEAM_ID  \
# 0    1630173  Precious Achiuwa  0022300755  FEB 10, 2024  1.610613e+09
# 1    1630173  Precious Achiuwa  0022300765  FEB 12, 2024  1.610613e+09
# 2    1630173  Precious Achiuwa  0022300778  FEB 14, 2024  1.610613e+09
# 3    1630173  Precious Achiuwa  0022300794  FEB 22, 2024  1.610613e+09
# 4    1630173  Precious Achiuwa  0022300816  FEB 24, 2024  1.610613e+09
#
#    VISITOR_TEAM_ID HOME_TEAM_NAME VISITOR_TEAM_NAME HOME_TEAM_ABBREVIATION  \
# 0     1.610613e+09       New York           Indiana                    NYK
# 1     1.610613e+09        Houston          New York                    HOU
# 2     1.610613e+09        Orlando          New York                    ORL
# 3     1.610613e+09   Philadelphia          New York                    PHI
# 4     1.610613e+09       New York            Boston                    NYK
#
#   VISITOR_TEAM_ABBREVIATION HOME_TEAM_NICKNAME VISITOR_TEAM_NICKNAME  \
# 0                       IND             Knicks                Pacers
# 1                       NYK            Rockets                Knicks
# 2                       NYK              Magic                Knicks
# 3                       NYK              76ers                Knicks
# 4                       BOS             Knicks               Celtics
#
#   GAME_TIME HOME_WL VISITOR_WL
# 0  07:30 PM   33-19      29-24
# 1  08:00 PM   23-27      33-19
# 2  07:00 PM   28-24      33-19
# 3  07:00 PM   30-20      33-19
# 4  08:30 PM   33-19      39-12

# %% [markdown]
# # Store Curated Data

# %%
def get_now(for_files:bool=False):
    """Return today's date.

    Args:
        for_files (bool): if True, return now's date for files (without - between them)

    """
    now = datetime.now()
    if for_files:
        return now.strftime("%Y%m%d__%H%M%S")
    return now.strftime("%Y-%m-%d %H-%M-%S")

# %%
def get_today():
    now = datetime.now()
    return now.strftime("%Y-%m-%d")

# %%
def store_dataframe_next_games(df):
    today = get_now()
    file_path = f"../dataset/player_next_games_{today}.csv"
    try:
        df.to_csv(file_path, index=False)
        print(f"DataFrame sauvegardé avec succès en tant que fichier CSV à : {file_path}")
    except Exception as e:
        print(f"Erreur lors de la sauvegarde du DataFrame : {e}")

# %%
def store_dataframe_player_stat(df):
    today = get_now()
    file_path = f"../dataset/player_stats_all_{today}.csv"
    try:
        df.to_csv(file_path, index=False)
        print(f"DataFrame sauvegardé avec succès en tant que fichier CSV à : {file_path}")
    except Exception as e:
        print(f"Erreur lors de la sauvegarde du DataFrame : {e}")

# %%
store_dataframe_next_games(stat_player_game_with_names)
# Out:
# DataFrame sauvegardé avec succès en tant que fichier CSV à : ../dataset/player_next_games_2024-02-09 19-18-07.csv

# %%
def concat_dataframe(df1, df2):
    df_concatene = pd.concat([df1, df2], axis=0)
    return df_concatene

# %%
all_players_stats_1 = pd.DataFrame("dataset/player_stats_all_2024-02-09 17-06-12.csv")
